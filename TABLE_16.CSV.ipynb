# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r"C:/Users/ANDERSON/Desktop/source.xlsx")
df
# Out:
#                                             Unnamed: 0  \
# 0                                                  NaN
# 1                               16  Structure of trade
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 220                                              NOTES
# 221                                                NaN
# 222  a. Primary exports include exports of agricult...
# 223                                                NaN
# 224  SOURCES\nColumns 1–4 and 7–10: World Bank 2007...
#
#                                             Unnamed: 1  Unnamed: 2 Unnamed: 3  \
# 0    … to have access to the resources needed for a...         NaN        NaN
# 1                                                  NaN         NaN        NaN
# ...

# %%
df.head(6)
# Out:
#                Unnamed: 0                                         Unnamed: 1  \
# 0                     NaN  … to have access to the resources needed for a...
# 1  16  Structure of trade                                                NaN
# 2                     NaN                                                NaN
# 3                     NaN                                                NaN
# 4                     NaN                                                NaN
# 5                     NaN                                                NaN
#
#    Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0         NaN        NaN        NaN        NaN        NaN        NaN
# 1         NaN        NaN        NaN        NaN        NaN        NaN
# 2         NaN        NaN        NaN        NaN        NaN        NaN
# 3         NaN        NaN        NaN        NaN        NaN        NaN
# 4         NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %%
df=  pd.read_excel(r"C:/Users/ANDERSON/Desktop/source.xlsx",header=9)
df
# Out:
#                                             Unnamed: 0 Unnamed: 1  Unnamed: 2  \
# 0                                                  NaN        NaN         NaN
# 1                                             HDI rank        NaN         NaN
# 2                                                  NaN        NaN         NaN
# 3                               HIGH HUMAN DEVELOPMENT        NaN         NaN
# 4                                                    1    Iceland         NaN
# ..                                                 ...        ...         ...
# 211                                              NOTES        NaN         NaN
# 212                                                NaN        NaN         NaN
# 213  a. Primary exports include exports of agricult...        NaN         NaN
# 214                                                NaN        NaN         NaN
# 215  SOURCES\nColumns 1–4 and 7–10: World Bank 2007...        NaN         NaN
#
# ...

# %%
df = df.dropna(how="all",axis=1)
df = df.dropna(how="all",axis=0)
df = df.reset_index(drop=True)
df.head(12)
# Out:
#                 Unnamed: 0   Unnamed: 1  \
# 0                      NaN          NaN
# 1                 HDI rank          NaN
# 2                      NaN          NaN
# 3   HIGH HUMAN DEVELOPMENT          NaN
# 4                        1      Iceland
# 5                        2       Norway
# 6                        3    Australia
# 7                        4       Canada
# 8                        5      Ireland
# 9                        6       Sweden
# 10                       7  Switzerland
# 11                       8        Japan
#
#                                    Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0   Imports of goods and services\n(% of GDP)        NaN        NaN
# 1                                         NaN        NaN        NaN
# 2                                        1990        NaN       2005
# 3                                         NaN        NaN        NaN
# 4                                          32        NaN         45
# ...

# %%
columns =[]
for c in df.columns:
    columns.append([str(v) for v in df[c][0:3] if pd.notnull(v)])

print(columns)
# Out:
# [['HDI rank'], [], ['Imports of goods and services\n(% of GDP)', '1990'], [], ['2005'], [], ['Exports of goods and services\n (% of GDP)', '1990'], [], ['2005'], [], ['1990'], [], ['2005'], [], ['1990'], [], ['2005'], [], ['1990'], [], ['2005'], [], ['2004-05c'], []]

# %%
columns = ['HDI rank','countries','Imports_of_goods_and_services_(% of GDP)_1990','reference_1',
       'Imports_of_goods_and_services_(% of GDP)_2005','reference_2', 'Exports_of_goods_and_services_ (% of GDP)_1990',
        'reference_3','Exports_of_goods_and_services_ (% of GDP)_2005','reference_4' ,
        'Primary_exportsa_ (% of merchandise exports)_1990','reference_5','Primary_exportsa_ (% of merchandise exports)_2005',
        'reference_6','Manufactured exports_(% of merchandise exports)_1990','reference_7', 
        'Manufactured_exports_ (% of merchandise exports)_2005','reference_8',
       'High_technology_exports_(% of manufactured exports)_1990','reference_9',
        'High_technology_exports_(% of manufactured exports)_2005','reference_10',
       'Terms_of_trade_ (2000=100)b_2004-05c','reference_11']

df.columns = columns



df = df.drop(np.arange(3), axis=0).reset_index(drop=True)
df.head()
# Out:
#                  HDI rank  countries  \
# 0  HIGH HUMAN DEVELOPMENT        NaN
# 1                       1    Iceland
# 2                       2     Norway
# 3                       3  Australia
# 4                       4     Canada
#
#   Imports_of_goods_and_services_(% of GDP)_1990 reference_1  \
# 0                                           NaN         NaN
# 1                                            32         NaN
# 2                                            34         NaN
# 3                                            16         NaN
# 4                                            26         NaN
#
#   Imports_of_goods_and_services_(% of GDP)_2005 reference_2  \
# 0                                           NaN         NaN
# 1                                            45         NaN
# 2                                            28         NaN
# 3                                            21           d
# 4                                            34           d
#
# ...

# %%
df = df.drop(np.arange(180,len(df)), axis=0).reset_index(drop=True)
df.tail(30)
# Out:
#                   HDI rank                           countries  \
# 150                    149                            Djibouti
# 151                    150                         Timor-Leste
# 152                    151                            Zimbabwe
# 153                    152                                Togo
# 154                    153                               Yemen
# 155                    154                              Uganda
# 156                    155                              Gambia
# 157  LOW HUMAN DEVELOPMENT                                 NaN
# 158                    156                             Senegal
# 159                    157                             Eritrea
# 160                    158                             Nigeria
# 161                    159       Tanzania (United Republic of)
# 162                    160                              Guinea
# 163                    161                              Rwanda
# ...

# %%
hdi_level = ["HIGH HUMAN DEVELOPMENT", "MEDIUM HUMAN DEVELOPMENT", "LOW HUMAN DEVELOPMENT"]
df = df.drop(df[df["HDI rank"].isin(hdi_level)].index, axis=0).reset_index(drop=True)
df.loc[:, "hdi_level"] = np.where(df["HDI rank"] > 155,"LOW HUMAN DEVELOPMENT",np.where(df["HDI rank"] > 70,"MEDIUM HUMAN DEVELOPMENT","HIGH HUMAN DEVELOPMENT"))
df.sort_values(by="HDI rank", inplace=True)
df.head()
# Out:
#   HDI rank  countries Imports_of_goods_and_services_(% of GDP)_1990  \
# 0        1    Iceland                                            32
# 1        2     Norway                                            34
# 2        3  Australia                                            16
# 3        4     Canada                                            26
# 4        5    Ireland                                            52
#
#   reference_1 Imports_of_goods_and_services_(% of GDP)_2005 reference_2  \
# 0         NaN                                            45         NaN
# 1         NaN                                            28         NaN
# 2         NaN                                            21           d
# 3         NaN                                            34           d
# 4         NaN                                            68           d
#
#   Exports_of_goods_and_services_ (% of GDP)_1990 reference_3  \
# ...

# %%
df.tail(5)
# Out:
#     HDI rank      countries Imports_of_goods_and_services_(% of GDP)_1990  \
# 172      173           Mali                                            34
# 173      174          Niger                                            22
# 174      175  Guinea-Bissau                                            37
# 175      176   Burkina Faso                                            24
# 176      177   Sierra Leone                                            24
#
#     reference_1 Imports_of_goods_and_services_(% of GDP)_2005 reference_2  \
# 172         NaN                                            37         NaN
# 173         NaN                                            24         NaN
# 174         NaN                                            55         NaN
# 175         NaN                                            22         NaN
# 176         NaN                                            43         NaN
#
#     Exports_of_goods_and_services_ (% of GDP)_1990 reference_3  \
# ...
